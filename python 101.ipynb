# %%
# to import the module
import pandas as pd

# %%
# to import as csv & separated
hagebau = pd.read_csv("C:/Users/yj_pc/Desktop/berlin/htw berlin/MPMD_Dateien/1.2 Fdns Data Analytics & Stats Prog/001_Data_CONFIDENTIAL/records_116007_from_2017-03-01_to_2017-03-31.csv", sep=',')
hagebau
# Out:
#        mainBusinessType  location                  datetime  \
# 0                    30    116007  2017-03-25T07:07:00.000Z
# 1                    30    116007  2017-03-25T07:10:00.000Z
# 2                    30    116007  2017-03-25T07:10:00.000Z
# 3                    30    116007  2017-03-25T07:10:00.000Z
# 4                    30    116007  2017-03-25T07:10:00.000Z
# 5                    30    116007  2017-03-25T07:10:00.000Z
# 6                    30    116007  2017-03-25T07:11:00.000Z
# 7                    30    116007  2017-03-25T07:13:00.000Z
# 8                    30    116007  2017-03-25T07:13:00.000Z
# 9                    30    116007  2017-03-25T07:13:00.000Z
# 10                   30    116007  2017-03-25T07:14:00.000Z
# 11                   30    116007  2017-03-25T07:21:00.000Z
# 12                   30    116007  2017-03-25T07:21:00.000Z
# 13                   30    116007  2017-03-25T07:21:00.000Z
# 14                   30    116007  2017-03-25T07:21:00.000Z
# ...

# %%
# filtering
filt=hagebau.dropna()

filt = filt[filt.grossPrice < 0]
filt

filt.count()

# to export csv
filt.to_csv("C:/Users/yj_pc/Desktop/testexport.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4f4d2a1d3365> in <module>()
#       1 # filtering
# ----> 2 filt=hagebau.dropna()
#       3
#       4 filt = filt[filt.grossPrice < 0]
#       5 filt
#
# NameError: name 'hagebau' is not defined

# %%
# to import as csv
hagebau = pd.read_csv("C:/Users/yj_pc/Desktop/berlin/htw berlin/MPMD_Dateien/1.2 Fdns Data Analytics & Stats Prog/001_Data_CONFIDENTIAL/records_116007_from_2017-03-01_to_2017-03-31.csv", sep = ';')

# to drop records with no values
hagebau.dropna()
hagebau.count()

# to get data type 
type(hagebau)

# to drop records with no values IN A PARTICULAR COLUMN
filt = hagebau.dropna(subset=['loyaltyId'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-a06346e2acdd> in <module>()
#      10
#      11 # to drop records with no values IN A PARTICULAR COLUMN
# ---> 12 filt = hagebau.dropna(subset=['loyaltyId'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4283                 check = indices == -1
#    4284                 if check.any():
# -> 4285                     raise KeyError(list(np.compress(check, subset)))
#    4286                 agg_obj = self.take(indices, axis=agg_axis)
#    4287
#
# KeyError: ['loyaltyId']

# %%
dict = {"ruthra":1,"haris":2}

# TO PRINT OUT INDICES
for asd in dict:
    print(asd)
# Out:
# ruthra
# haris

# %%
dict = {"ruthra":1,"haris":2}

# TO PRINT OUT VALUES
for asd in dict.values():
    print(asd)
# Out:
# 1
# 2
